# %% [markdown]
# # Growth Visualization
#
# The following file is meant to display the trends that exist within each of the available datasets. In this file, the we will be examining these different trends through the perspective of the five different regions of the United States, defined by official U.S as the following:
#
#
#
# **Northeast Region (States: Connecticut, Maine, Massachusetts, New Hampshire, Rhode Island, Vermont, New Jersey, New York, Pennsylvania)**
#
# **Midwest Region (States: Indiana, Illinois, Michigan, Ohio, Wisconsin, Iowa, Nebraska, Kansas, North Dakota, Minnesota, South Dakota,Missouri)**
#
# **South Region (States: Delaware, Florida, Georgia, Maryland, North Carolina, South Carolina, Virginia, West Virginia, Alabama, Kentucky,Mississippi, Tennessee, Arkansas, Louisiana, Oklahoma, Texas)**
#
# **West Region (States: Arizona, Colorado, Idaho, New Mexico, Montana, Utah, Nevada, Wyoming, California, Oregon, Washington)**
#
# **Alaska Region: (States: Alaska)**
# **Hawaii Region: (States: Hawaii)**
#
#
#
# For the purposes of being considered a territory, we will not be including the District of Columbia in our calculation of the South. In addition to this, we will be defining the states of Alaska and Hawaii as their own regions, due to their lack of presence on the continental United States. It would not make sense to use the data for Alaska or Hawaii to calculate the Regional Growth Index for a state like Wyoming, since they are so far away.

# %%
# Importing Packages Use for Visualization

import matplotlib.pyplot as plt
import scipy.stats as scs
import statsmodels.stats.api as sms
import statsmodels.api as sm
import pandas as pd
import numpy as np
import matplotlib.ticker as ticker

# %%
US_Census_df = pd.read_csv('United_States_Census_Data.csv')
US_Fertility_df = pd.read_csv('United_States_Fertility_Rates.csv')
US_Median_Income_df = pd.read_csv('United_States_Median_Income_by_State.csv')
US_Unemployment_df = pd.read_csv('United_States_Unemployment_Data.csv')

# %% [markdown]
# # Census Visualizations

# %%
formatter = ticker.FuncFormatter(lambda x, pos: '{:,}'.format(int(x)))
pop_years = ['1910', '1920', '1930', '1940', '1950', '1960', '1970', '1980', '1990', '2000', '2010', '2020']

def region_condenser_pop(idx_lst):
    regional_data = [0 for i in range(12)]

    for i in idx_lst:
        data = US_Census_df.iloc[i].iloc[2:]  
    
        data_as_integers = data.str.replace(',', '').astype(int)

        storage = data_as_integers.tolist()
        storage.reverse()

        regional_data = [sum(i) for i in zip(regional_data, storage)]
    
    return regional_data

# %% [markdown]
# ### Northeast Regional Population Data Visualization

# %%
northeast_indices = [6, 18, 20, 28, 38, 44, 39, 31, 37]

# %%
plt.figure(figsize=(10, 10))
plt.plot(pop_years, region_condenser_pop(northeast_indices))
plt.xlabel('Years of Census')
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=2))
plt.ylabel('Number of Regional Residents')
plt.title('Northeast Population over Years')
plt.grid(True)
plt.gca().yaxis.set_major_formatter(formatter)


directory_path = '/Users/emmanuely/Desktop/CodeFolder/Region_Growth_Projections/Figure_visualizations/Northeast_region_visuals/'

plt.savefig(directory_path + 'Northeast_region_population.jpeg')
plt.show()

# %% [markdown]
# ### Midwest Regional Population Data Visualization

# %%
midwest_indices = [13, 12, 21, 34, 48, 14, 26, 15, 33, 22, 40, 24]

# %%
plt.figure(figsize=(10, 10))
plt.plot(pop_years, region_condenser_pop(midwest_indices))
plt.xlabel('Years of Census')
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=2))
plt.ylabel('Number of Regional Residents')
plt.title('Midwest Population over Years')
plt.grid(True)
plt.gca().yaxis.set_major_formatter(formatter)


directory_path_midwest = '/Users/emmanuely/Desktop/CodeFolder/Region_Growth_Projections/Figure_visualizations/Midwest_region_visuals/'

plt.savefig(directory_path_midwest + 'Midwest_region_population.jpeg')
plt.show()

# %% [markdown]
# ### South Regional Population Data Visualization

# %%
south_indices = [7, 8, 9, 19, 32, 39, 45, 47, 0, 16, 23, 41, 3, 17, 35, 42]

# %%
plt.figure(figsize=(10, 10))
plt.plot(pop_years, region_condenser_pop(south_indices))
plt.xlabel('Years of Census')
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=2))
plt.ylabel('Number of Regional Residents')
plt.title('South Population over Years')
plt.grid(True)
plt.gca().yaxis.set_major_formatter(formatter)


directory_path_south = '/Users/emmanuely/Desktop/CodeFolder/Region_Growth_Projections/Figure_visualizations/South_region_visuals/'

plt.savefig(directory_path_south + 'South_region_population.jpeg')
plt.show()

# %% [markdown]
# ### West Regional Population Data Visualization

# %%
west_indices = [2, 5, 11, 30, 25, 43, 27, 49, 4, 36, 46]

# %%
plt.figure(figsize=(10, 10))
plt.plot(pop_years, region_condenser_pop(west_indices))
plt.xlabel('Years of Census')
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=2))
plt.ylabel('Number of Regional Residents')
plt.title('West Population over Years')
plt.grid(True)
plt.gca().yaxis.set_major_formatter(formatter)


directory_path_west = '/Users/emmanuely/Desktop/CodeFolder/Region_Growth_Projections/Figure_visualizations/West_region_visuals/'

plt.savefig(directory_path_west + 'West_region_population.jpeg')
plt.show()

# %% [markdown]
# ### Alaska Regional Population Data Visualization

# %%
plt.figure(figsize=(10, 10))
plt.plot(pop_years, region_condenser_pop([1]))
plt.xlabel('Years of Census')
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=2))
plt.ylabel('Number of Regional Residents')
plt.title('Alaska Population over Years')
plt.grid(True)
plt.gca().yaxis.set_major_formatter(formatter)


directory_path_alaska = '/Users/emmanuely/Desktop/CodeFolder/Region_Growth_Projections/Figure_visualizations/Alaska_region_visuals/'

plt.savefig(directory_path_alaska + 'Alaska_region_population.jpeg')
plt.show()

# %% [markdown]
# ### Hawaii Regional Population Data Visualization

# %%
plt.figure(figsize=(10, 10))
plt.plot(pop_years, region_condenser_pop([10]))
plt.xlabel('Years of Census')
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=2))
plt.ylabel('Number of Regional Residents')
plt.title('Hawaii Population over Years')
plt.grid(True)
plt.gca().yaxis.set_major_formatter(formatter)


directory_path_hawaii = '/Users/emmanuely/Desktop/CodeFolder/Region_Growth_Projections/Figure_visualizations/Hawaii_region_visuals/'

plt.savefig(directory_path_hawaii + 'Hawaii_region_population.jpeg')
plt.show()

# %% [markdown]
# # Fertility Visualizations

# %%
fertility_years = ['2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021']

def region_condenser_fertility(idx_lst):
    fertility_data = [0 for i in range(8)]

    for i in idx_lst:
        data = US_Fertility_df.iloc[i].iloc[2:] 

        storage = data.tolist()

        fertility_data = [sum(i) for i in zip(fertility_data, storage)]

    
    return fertility_data

# %% [markdown]
# ### Northeast Regional Fertility Data Visualization

# %%
plt.figure(figsize=(10, 10))
plt.plot(fertility_years, region_condenser_fertility(northeast_indices))
plt.xlabel('Years for Fertility')
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=1))
plt.ylabel('Number of Births')
plt.title('Northeast Regional Births over Years')
plt.grid(True)
plt.gca().yaxis.set_major_formatter(formatter)


plt.savefig(directory_path + 'Northeast_region_fertility.jpeg')
plt.show()

# %% [markdown]
# ### Midwest Regional Fertility Data Visualization

# %%
plt.figure(figsize=(10, 10))
plt.plot(fertility_years, region_condenser_fertility(midwest_indices))
plt.xlabel('Years for Fertility')
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=1))
plt.ylabel('Number of Births')
plt.title('Midwest Regional Births over Years')
plt.grid(True)
plt.gca().yaxis.set_major_formatter(formatter)


plt.savefig(directory_path_midwest + 'Midwest_region_fertility.jpeg')
plt.show()

# %% [markdown]
# ### South Regional Fertilty Data Visualization

# %%
plt.figure(figsize=(10, 10))
plt.plot(fertility_years, region_condenser_fertility(south_indices))
plt.xlabel('Years for Fertility')
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=1))
plt.ylabel('Number of Births')
plt.title('South Regional Births over Years')
plt.grid(True)
plt.gca().yaxis.set_major_formatter(formatter)


plt.savefig(directory_path_south + 'South_region_fertility.jpeg')
plt.show()

# %% [markdown]
# ### West Regional Fertility Data Visualization

# %%
plt.figure(figsize=(10, 10))
plt.plot(fertility_years, region_condenser_fertility(west_indices))
plt.xlabel('Years for Fertility')
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=1))
plt.ylabel('Number of Births')
plt.title('West Regional Births over Years')
plt.grid(True)
plt.gca().yaxis.set_major_formatter(formatter)


plt.savefig(directory_path_west + 'West_region_fertility.jpeg')
plt.show()

# %% [markdown]
# ### Alaska Regional Fertility Data Visualization

# %%
plt.figure(figsize=(10, 10))
plt.plot(fertility_years, region_condenser_fertility([1]))
plt.xlabel('Years for Fertility')
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=1))
plt.ylabel('Number of Births')
plt.title('Alaska Regional Births over Years')
plt.grid(True)
plt.gca().yaxis.set_major_formatter(formatter)


plt.savefig(directory_path_alaska + 'Alaska_region_fertility.jpeg')
plt.show()

# %% [markdown]
# ### Hawaii Regional Fertility Data Visualization

# %%
plt.figure(figsize=(10, 10))
plt.plot(fertility_years, region_condenser_fertility([10]))
plt.xlabel('Years for Fertility')
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=1))
plt.ylabel('Number of Births')
plt.title('Hawaii Regional Births over Years')
plt.grid(True)
plt.gca().yaxis.set_major_formatter(formatter)


plt.savefig(directory_path_hawaii + 'Hawaii_region_fertility.jpeg')
plt.show()

# %% [markdown]
# **Note:** If we take a look at the year 2020, for all regions apart from Alaska and Hawaii there was a steep decrease in births. This is due to the COVID-19 pandemic which we can see is taking full effect here. The infection rate on the continental USA was high, so I can imagine that not many people wanted to go out and have kids. This is why regions like Hawaii and Alaska don't seem to be affected as much in 2020, as they are not part of the continental USA.

# %% [markdown]
# # Median Income Visualizations

# %%
remaining_med_columns = US_Median_Income_df.columns[2:]
median_income_years = [col.split(' ')[0] if ' Median Income' in col else col for col in remaining_med_columns]

def region_condenser_med_inc(idx_lst):
    med_inc_data = [0 for i in range(38)]

    for i in idx_lst:
        data = US_Median_Income_df.iloc[i].iloc[2:]

        storage = data.tolist()

        med_inc_data = [sum(i) for i in zip(med_inc_data, storage)]

    
    return med_inc_data

# %% [markdown]
# ### Northeast Regional Median Income Data Visualization

# %%
plt.figure(figsize=(10, 10))
plt.plot(median_income_years, region_condenser_med_inc(northeast_indices))
plt.xlabel('Years for Median Income')
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=5))
plt.ylabel('Median Income(USD)')
plt.title('Northeast Regional Median Income over Years (USD)')
plt.grid(True)
plt.gca().yaxis.set_major_formatter(formatter)


plt.savefig(directory_path + 'Northeast_region_median_income.jpeg')
plt.show()

# %% [markdown]
# ### Midwest Regional Median Income Data Visualization

# %%
plt.figure(figsize=(10, 10))
plt.plot(median_income_years, region_condenser_med_inc(midwest_indices))
plt.xlabel('Years for Median Income')
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=5))
plt.ylabel('Median Income(USD)')
plt.title('Midwest Regional Median Income over Years (USD)')
plt.grid(True)
plt.gca().yaxis.set_major_formatter(formatter)


plt.savefig(directory_path_midwest + 'Midwest_region_median_income.jpeg')
plt.show()

# %% [markdown]
# ### South Regional Median Income Data Visualization

# %%
plt.figure(figsize=(10, 10))
plt.plot(median_income_years, region_condenser_med_inc(south_indices))
plt.xlabel('Years for Median Income')
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=5))
plt.ylabel('Median Income(USD)')
plt.title('South Regional Median Income over Years (USD)')
plt.grid(True)
plt.gca().yaxis.set_major_formatter(formatter)


plt.savefig(directory_path_south + 'South_region_median_income.jpeg')
plt.show()

# %% [markdown]
# ### West Regional Median Income Data Visualization

# %%
plt.figure(figsize=(10, 10))
plt.plot(median_income_years, region_condenser_med_inc(west_indices))
plt.xlabel('Years for Median Income')
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=5))
plt.ylabel('Median Income(USD)')
plt.title('West Regional Median Income over Years (USD)')
plt.grid(True)
plt.gca().yaxis.set_major_formatter(formatter)


plt.savefig(directory_path_west + 'West_region_median_income.jpeg')
plt.show()

# %% [markdown]
# ### Alaska Regional Median Income Data Visualization

# %%
plt.figure(figsize=(10, 10))
plt.plot(median_income_years, region_condenser_med_inc([1]))
plt.xlabel('Years for Median Income')
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=5))
plt.ylabel('Median Income(USD)')
plt.title('Alaska Regional Median Income over Years (USD)')
plt.grid(True)
plt.gca().yaxis.set_major_formatter(formatter)


plt.savefig(directory_path_alaska + 'Alaska_region_median_income.jpeg')
plt.show()

# %% [markdown]
# ### Hawaii Regional Median Income Data Visualization

# %%
plt.figure(figsize=(10, 10))
plt.plot(median_income_years, region_condenser_med_inc([10]))
plt.xlabel('Years for Median Income')
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=5))
plt.ylabel('Median Income(USD)')
plt.title('Hawaii Regional Median Income over Years (USD)')
plt.grid(True)
plt.gca().yaxis.set_major_formatter(formatter)


plt.savefig(directory_path_hawaii + 'Hawaii_region_median_income.jpeg')
plt.show()

# %% [markdown]
# # Unemployment Visualizations

# %%
remaining_unemployment_columns = US_Unemployment_df.columns[2:]
unemployment_years = [col.split('_')[1] if 'Unemployed_' in col else col for col in remaining_unemployment_columns]


def region_condenser_unemployed(idx_lst):
    unemployed_data = [0 for i in range(24)]

    for i in idx_lst:
        data = US_Unemployment_df.iloc[i].iloc[2:]

        storage = data.tolist()

        unemployed_data = [sum(i) for i in zip(unemployed_data, storage)]

    
    return unemployed_data

# %% [markdown]
# ### Northeast Regional Unemployment Data Visualization

# %%
plt.figure(figsize=(10, 10))
plt.plot(unemployment_years, region_condenser_unemployed(northeast_indices))
plt.xlabel('Years for Unemployment')
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=5))
plt.ylabel('Number of Unemployed People')
plt.title('Northeast Regional Unemployment Numbers over Years')
plt.grid(True)



plt.gca().yaxis.set_major_formatter(formatter)


plt.savefig(directory_path + 'Northeast_region_unemployment.jpeg')
plt.show()

# %% [markdown]
# ### Midwest Regional Unemployment Data Visualization

# %%
plt.figure(figsize=(10, 10))
plt.plot(unemployment_years, region_condenser_unemployed(midwest_indices))
plt.xlabel('Years for Unemployment')
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=5))
plt.ylabel('Number of Unemployed People')
plt.title('Midwest Regional Unemployment Numbers over Years')
plt.grid(True)
plt.gca().yaxis.set_major_formatter(ticker.ScalarFormatter(useOffset=False, useMathText=True))
plt.gca().yaxis.set_major_formatter(formatter)


plt.savefig(directory_path_midwest + 'Midwest_region_unemployment.jpeg')
plt.show()

# %% [markdown]
# ### South Regional Unemployment Data Visualization

# %%
plt.figure(figsize=(10, 10))
plt.plot(unemployment_years, region_condenser_unemployed(south_indices))
plt.xlabel('Years for Unemployment')
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=5))
plt.ylabel('Number of Unemployed People')
plt.title('South Regional Unemployment Numbers over Years')
plt.grid(True)
plt.gca().yaxis.set_major_formatter(formatter)


plt.savefig(directory_path_midwest + 'Midwest_region_unemployment.jpeg')
plt.show()

# %% [markdown]
# ### West Regional Unemployment Data Visualization

# %%
plt.figure(figsize=(10, 10))
plt.plot(unemployment_years, region_condenser_unemployed(west_indices))
plt.xlabel('Years for Unemployment')
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=5))
plt.ylabel('Number of Unemployed People')
plt.title('West Regional Unemployment Numbers over Years')
plt.grid(True)
plt.gca().yaxis.set_major_formatter(formatter)


plt.savefig(directory_path_west + 'West_region_unemployment.jpeg')
plt.show()

# %% [markdown]
# ### Alaska Regional Unemployment Data Visualization

# %%
plt.figure(figsize=(10, 10))
plt.plot(unemployment_years, region_condenser_unemployed([1]))
plt.xlabel('Years for Unemployment')
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=5))
plt.ylabel('Number of Unemployed People')
plt.title('Alaska Regional Unemployment Numbers over Years')
plt.grid(True)
plt.gca().yaxis.set_major_formatter(formatter)


plt.savefig(directory_path_alaska + 'Alaska_region_unemployment.jpeg')
plt.show()

# %% [markdown]
# ### Hawaii Regional Unemployment Data Visualization

# %%
plt.figure(figsize=(10, 10))
plt.plot(unemployment_years, region_condenser_unemployed([10]))
plt.xlabel('Years for Unemployment')
plt.gca().xaxis.set_major_locator(ticker.MultipleLocator(base=5))
plt.ylabel('Number of Unemployed People')
plt.title('Hawaii Regional Unemployment Numbers over Years')
plt.grid(True)
plt.gca().yaxis.set_major_formatter(formatter)


plt.savefig(directory_path_hawaii + 'Hawaii_region_unemployment.jpeg')
plt.show()
